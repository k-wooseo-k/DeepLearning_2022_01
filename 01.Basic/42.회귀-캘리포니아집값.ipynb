# %% [markdown]
# # 회귀 - 캘리포니아 하우징

# %%
import numpy as np
import pandas as pd
from sklearn.datasets import fetch_california_housing
house = fetch_california_housing()

# %%
df = pd.DataFrame(house.data, columns=house.feature_names)
df['target'] = house.target
df.head()
# Out:
#    MedInc  HouseAge  AveRooms  AveBedrms  ...  AveOccup  Latitude  Longitude  target
# 0  8.3252      41.0  6.984127   1.023810  ...  2.555556     37.88    -122.23   4.526
# 1  8.3014      21.0  6.238137   0.971880  ...  2.109842     37.86    -122.22   3.585
# 2  7.2574      52.0  8.288136   1.073446  ...  2.802260     37.85    -122.24   3.521
# 3  5.6431      52.0  5.817352   1.073059  ...  2.547945     37.85    -122.25   3.413
# 4  3.8462      52.0  6.281853   1.081081  ...  2.181467     37.85    -122.25   3.422
#
# [5 rows x 9 columns]

# %%
df.shape
# Out:
# (20640, 9)

# %% [markdown]
# - Train/test dataset 분리

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(
    house.data, house.target, test_size=0.1, random_state=2022
)
X_train.shape, X_test.shape, y_train.shape, y_test.shape
# Out:
# ((18576, 8), (2064, 8), (18576,), (2064,))

# %% [markdown]
# - 모델 정의/설정/학습

# %%
import tensorflow as tf
seed = 2022
np.random.seed(seed)
tf.random.set_seed(seed)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

# %%
model = Sequential([
    Dense(20, input_dim=8, activation='relu'),
    Dense(8, activation='relu'),
    Dense(1)
])
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 20)                180
#
#  dense_1 (Dense)             (None, 8)                 168
#
#  dense_2 (Dense)             (None, 1)                 9
#
# =================================================================
# Total params: 357
# Trainable params: 357
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(optimizer='adam', loss='mean_squared_error')

# %%
hist = model.fit(X_train, y_train, validation_split=0.2, epochs=100, batch_size=128)
# Out:
# Epoch 1/100
# 117/117 [==============================] - 1s 3ms/step - loss: 924.8505 - val_loss: 11.1883
# Epoch 2/100
# 117/117 [==============================] - 0s 2ms/step - loss: 13.7025 - val_loss: 9.9141
# Epoch 3/100
# 117/117 [==============================] - 0s 2ms/step - loss: 12.0063 - val_loss: 8.7134
# Epoch 4/100
# 117/117 [==============================] - 0s 2ms/step - loss: 10.4420 - val_loss: 7.8351
# Epoch 5/100
# 117/117 [==============================] - 0s 2ms/step - loss: 8.9745 - val_loss: 6.4690
# Epoch 6/100
# 117/117 [==============================] - 0s 2ms/step - loss: 7.3797 - val_loss: 5.3087
# Epoch 7/100
# 117/117 [==============================] - 0s 2ms/step - loss: 6.1005 - val_loss: 4.3859
# Epoch 8/100
# 117/117 [==============================] - 0s 2ms/step - loss: 4.9349 - val_loss: 3.6842
# Epoch 9/100
# 117/117 [==============================] - 0s 2ms/step - loss: 3.8383 - val_loss: 2.0832
# Epoch 10/100
# 117/117 [==============================] - 0s 2ms/step - loss: 1.1136 - val_loss: 0.8826
# Epoch 11/100
# 117/117 [==============================] - 0s 2ms/step - loss: 0.8685 - val_loss: 0.8360
# Epoch 12/100
# 117/117 [==============================] - 0s 2ms/step - loss: 0.8190 - val_loss: 0.7465
# Epoch 13/100
# 117/117 [==============================] - 0s 2ms/step - loss: 0.7829 - val_loss: 0.8023
# Epoch 14/100
# 117/117 [==============================] - 0s 2ms/step - loss: 0.7470 - val_loss: 0.7457
# Epoch 15/100
# 117/117 [==============================] - 0s 2ms/step - loss: 0.7557 - val_loss: 0.6864
# Epoch 16/100
# 117/117 [==============================] - 0s 2ms/step - loss: 0.7253 - val_loss: 0.7170
# Epoch 17/100
# 117/117 [==============================] - 0s 2ms/step - loss: 0.7202 - val_loss: 0.6691
# Epoch 18/100
# 117/117 [==============================] - 0s 2ms/step - loss: 0.6818 - val_loss: 0.6667
# Epoch 19/100
# 117/117 [==============================] - 0s 2ms/step - loss: 0.6783 - val_loss: 0.7195
# Epoch 20/100
# 117/117 [==============================] - 0s 2ms/step - loss: 0.6855 - val_loss: 0.6991
# Epoch 21/100
# 117/117 [==============================] - 0s 2ms/step - loss: 0.6920 - val_loss: 0.6538
# Epoch 22/100
# 117/117 [==============================] - 0s 2ms/step - loss: 0.6833 - val_loss: 1.0597
# Epoch 23/100
# 117/117 [==============================] - 0s 2ms/step - loss: 0.6865 - val_loss: 0.6567
# Epoch 24/100
# 117/117 [==============================] - 0s 2ms/step - loss: 0.6845 - val_loss: 0.7007
# Epoch 25/100
# 117/117 [==============================] - 0s 2ms/step - loss: 0.7329 - val_loss: 0.8036
# Epoch 26/100
# 117/117 [==============================] - 0s 2ms/step - loss: 0.6711 - val_loss: 0.6415
# Epoch 27/100
# 117/117 [==============================] - 0s 2ms/step - loss: 0.6624 - val_loss: 0.6275
# Epoch 28/100
# 117/117 [==============================] - 0s 2ms/step - loss: 0.6840 - val_loss: 0.6922
# Epoch 29/100
# 117/117 [==============================] - 0s 2ms/step - loss: 0.7448 - val_loss: 0.7068
# Epoch 30/100
# 117/117 [==============================] - 0s 2ms/step - loss: 0.6947 - val_loss: 1.4534
# Epoch 31/100
# 117/117 [==============================] - 0s 2ms/step - loss: 0.7420 - val_loss: 0.6161
# Epoch 32/100
# 117/117 [==============================] - 0s 2ms/step - loss: 0.6563 - val_loss: 0.6176
# Epoch 33/100
# 117/117 [==============================] - 0s 2ms/step - loss: 0.6518 - val_loss: 1.0189
# Epoch 34/100
# 117/117 [==============================] - 0s 2ms/step - loss: 0.6955 - val_loss: 0.8068
# Epoch 35/100
# 117/117 [==============================] - 0s 2ms/step - loss: 0.6709 - val_loss: 0.8924
# Epoch 36/100
# 117/117 [==============================] - 0s 2ms/step - loss: 0.8750 - val_loss: 0.7324
# Epoch 37/100
# 117/117 [==============================] - 0s 2ms/step - loss: 1.1345 - val_loss: 1.5042
# Epoch 38/100
# 117/117 [==============================] - 0s 2ms/step - loss: 0.7448 - val_loss: 0.7940
# Epoch 39/100
# 117/117 [==============================] - 0s 2ms/step - loss: 0.7597 - val_loss: 0.7932
# Epoch 40/100
# 117/117 [==============================] - 0s 2ms/step - loss: 0.6645 - val_loss: 0.6085
# Epoch 41/100
# 117/117 [==============================] - 0s 2ms/step - loss: 0.7212 - val_loss: 5.0056
# Epoch 42/100
# 117/117 [==============================] - 0s 2ms/step - loss: 0.9609 - val_loss: 0.7618
# Epoch 43/100
# 117/117 [==============================] - 0s 2ms/step - loss: 0.7996 - val_loss: 0.6097
# Epoch 44/100
# 117/117 [==============================] - 0s 2ms/step - loss: 0.7307 - val_loss: 0.5934
# Epoch 45/100
# 117/117 [==============================] - 0s 2ms/step - loss: 0.8780 - val_loss: 0.6591
# Epoch 46/100
# 117/117 [==============================] - 0s 2ms/step - loss: 1.0519 - val_loss: 0.9561
# Epoch 47/100
# 117/117 [==============================] - 0s 2ms/step - loss: 0.7979 - val_loss: 0.5941
# Epoch 48/100
# 117/117 [==============================] - 0s 2ms/step - loss: 0.6552 - val_loss: 0.9042
# Epoch 49/100
# 117/117 [==============================] - 0s 2ms/step - loss: 1.1116 - val_loss: 0.5954
# Epoch 50/100
# 117/117 [==============================] - 0s 2ms/step - loss: 0.8673 - val_loss: 5.2047
# Epoch 51/100
# 117/117 [==============================] - 0s 2ms/step - loss: 1.1892 - val_loss: 1.9673
# Epoch 52/100
# 117/117 [==============================] - 0s 2ms/step - loss: 1.0250 - val_loss: 0.5861
# Epoch 53/100
# 117/117 [==============================] - 0s 2ms/step - loss: 0.7549 - val_loss: 0.5821
# Epoch 54/100
# 117/117 [==============================] - 0s 2ms/step - loss: 1.1009 - val_loss: 5.0128
# Epoch 55/100
# 117/117 [==============================] - 0s 2ms/step - loss: 10.0376 - val_loss: 0.5981
# Epoch 56/100
# 117/117 [==============================] - 0s 2ms/step - loss: 0.7339 - val_loss: 0.8933
# Epoch 57/100
# 117/117 [==============================] - 0s 2ms/step - loss: 0.8369 - val_loss: 1.3117
# Epoch 58/100
# 117/117 [==============================] - 0s 2ms/step - loss: 0.8710 - val_loss: 1.0300
# Epoch 59/100
# 117/117 [==============================] - 0s 2ms/step - loss: 0.7764 - val_loss: 1.0249
# Epoch 60/100
# 117/117 [==============================] - 0s 2ms/step - loss: 2.6127 - val_loss: 0.7617
# Epoch 61/100
# 117/117 [==============================] - 0s 2ms/step - loss: 0.9044 - val_loss: 0.9658
# Epoch 62/100
# 117/117 [==============================] - 0s 2ms/step - loss: 7.1692 - val_loss: 1.5485
# Epoch 63/100
# 117/117 [==============================] - 0s 2ms/step - loss: 0.7737 - val_loss: 0.5724
# Epoch 64/100
# 117/117 [==============================] - 0s 2ms/step - loss: 0.6487 - val_loss: 0.7043
# Epoch 65/100
# 117/117 [==============================] - 0s 2ms/step - loss: 0.7229 - val_loss: 0.6587
# Epoch 66/100
# 117/117 [==============================] - 0s 2ms/step - loss: 0.6193 - val_loss: 0.6514
# Epoch 67/100
# 117/117 [==============================] - 0s 2ms/step - loss: 0.6372 - val_loss: 0.5988
# Epoch 68/100
# 117/117 [==============================] - 0s 2ms/step - loss: 0.6173 - val_loss: 1.4101
# Epoch 69/100
# 117/117 [==============================] - 0s 2ms/step - loss: 0.8399 - val_loss: 0.6179
# Epoch 70/100
# 117/117 [==============================] - 0s 2ms/step - loss: 0.9309 - val_loss: 0.8425
# Epoch 71/100
# 117/117 [==============================] - 0s 2ms/step - loss: 0.6239 - val_loss: 1.1288
# Epoch 72/100
# 117/117 [==============================] - 0s 2ms/step - loss: 0.9092 - val_loss: 2.9604
# Epoch 73/100
# 117/117 [==============================] - 0s 2ms/step - loss: 1.0533 - val_loss: 0.5799
# Epoch 74/100
# 117/117 [==============================] - 0s 2ms/step - loss: 1.3742 - val_loss: 3.6063
# Epoch 75/100
# 117/117 [==============================] - 0s 2ms/step - loss: 1.2552 - val_loss: 6.0691
# Epoch 76/100
# 117/117 [==============================] - 0s 2ms/step - loss: 1.1493 - val_loss: 1.0344
# Epoch 77/100
# 117/117 [==============================] - 0s 2ms/step - loss: 0.9265 - val_loss: 0.8679
# Epoch 78/100
# 117/117 [==============================] - 0s 2ms/step - loss: 0.7320 - val_loss: 0.7087
# Epoch 79/100
# 117/117 [==============================] - 0s 2ms/step - loss: 1.0781 - val_loss: 0.6303
# Epoch 80/100
# 117/117 [==============================] - 0s 2ms/step - loss: 0.6344 - val_loss: 0.5924
# Epoch 81/100
# 117/117 [==============================] - 0s 2ms/step - loss: 0.6199 - val_loss: 0.5981
# Epoch 82/100
# 117/117 [==============================] - 0s 2ms/step - loss: 0.7282 - val_loss: 8.8720
# Epoch 83/100
# 117/117 [==============================] - 0s 2ms/step - loss: 26.2781 - val_loss: 0.6201
# Epoch 84/100
# 117/117 [==============================] - 0s 2ms/step - loss: 1.0708 - val_loss: 1.2066
# Epoch 85/100
# 117/117 [==============================] - 0s 2ms/step - loss: 0.6836 - val_loss: 0.5710
# Epoch 86/100
# 117/117 [==============================] - 0s 2ms/step - loss: 0.6373 - val_loss: 0.6324
# Epoch 87/100
# 117/117 [==============================] - 0s 2ms/step - loss: 0.6808 - val_loss: 0.5733
# Epoch 88/100
# 117/117 [==============================] - 0s 2ms/step - loss: 0.5986 - val_loss: 0.7622
# Epoch 89/100
# 117/117 [==============================] - 0s 2ms/step - loss: 0.7605 - val_loss: 0.6556
# Epoch 90/100
# 117/117 [==============================] - 0s 2ms/step - loss: 0.6558 - val_loss: 0.9234
# Epoch 91/100
# 117/117 [==============================] - 0s 2ms/step - loss: 0.6304 - val_loss: 0.6244
# Epoch 92/100
# 117/117 [==============================] - 0s 2ms/step - loss: 0.5950 - val_loss: 0.6475
# Epoch 93/100
# 117/117 [==============================] - 0s 2ms/step - loss: 0.6840 - val_loss: 0.6452
# Epoch 94/100
# 117/117 [==============================] - 0s 2ms/step - loss: 0.6172 - val_loss: 0.5614
# Epoch 95/100
# 117/117 [==============================] - 0s 2ms/step - loss: 0.6300 - val_loss: 0.5806
# Epoch 96/100
# 117/117 [==============================] - 0s 2ms/step - loss: 0.6387 - val_loss: 50.5448
# Epoch 97/100
# 117/117 [==============================] - 0s 2ms/step - loss: 6.3235 - val_loss: 1.9378
# Epoch 98/100
# 117/117 [==============================] - 0s 2ms/step - loss: 0.9254 - val_loss: 0.5981
# Epoch 99/100
# 117/117 [==============================] - 0s 2ms/step - loss: 0.5984 - val_loss: 0.8691
# Epoch 100/100
# 117/117 [==============================] - 0s 2ms/step - loss: 0.6289 - val_loss: 0.5811

# %% [markdown]
# - 학습과정 시각화

# %%
y_loss = hist.history['loss']
y_vloss = hist.history['val_loss']
xs = np.arange(6, len(y_loss)+6)

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(12,8))
plt.plot(xs, y_loss, label='train loss')
plt.plot(xs, y_vloss, label='validation loss')
plt.legend()
plt.grid()
plt.ylim([0,10])
plt.xlabel('Epoch')
plt.show()

# %% [markdown]
# ### case 2) 모델 재정의, 콜백 함수 사용

# %%
model2 = Sequential([
    Dense(10, input_dim=8, activation='relu'),
    Dense(16, activation='relu'),
    Dense(6, activation='relu'),
    Dense(1)
])
model2.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_3 (Dense)             (None, 10)                90
#
#  dense_4 (Dense)             (None, 16)                176
#
#  dense_5 (Dense)             (None, 6)                 102
#
#  dense_6 (Dense)             (None, 1)                 7
#
# =================================================================
# Total params: 375
# Trainable params: 375
# Non-trainable params: 0
# _________________________________________________________________

# %%
model2.compile(optimizer='rmsprop', loss='mean_squared_error')

# %%
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping
model_path = 'california_house2.h5'
checkpoint = ModelCheckpoint(
    model_path, monitor='val_loss', verbose=1, save_best_only=True
)
early_stop = EarlyStopping(patience=30)

# %%
hist2 = model2.fit(X_train, y_train, validation_split=0.2, epochs=1000, batch_size=128, verbose=0,
                   callbacks=[checkpoint, early_stop])
# Out:
# Epoch 00001: val_loss improved from inf to 3.18998, saving model to california_house2.h5
#
# Epoch 00002: val_loss improved from 3.18998 to 1.32375, saving model to california_house2.h5
#
# Epoch 00003: val_loss did not improve from 1.32375
#
# Epoch 00004: val_loss improved from 1.32375 to 1.25634, saving model to california_house2.h5
#
# Epoch 00005: val_loss improved from 1.25634 to 1.24165, saving model to california_house2.h5
#
# Epoch 00006: val_loss did not improve from 1.24165
#
# Epoch 00007: val_loss did not improve from 1.24165
#
# Epoch 00008: val_loss did not improve from 1.24165
#
# Epoch 00009: val_loss improved from 1.24165 to 1.16963, saving model to california_house2.h5
#
# Epoch 00010: val_loss improved from 1.16963 to 1.14868, saving model to california_house2.h5
#
# Epoch 00011: val_loss did not improve from 1.14868
#
# Epoch 00012: val_loss did not improve from 1.14868
#
# Epoch 00013: val_loss did not improve from 1.14868
#
# Epoch 00014: val_loss improved from 1.14868 to 1.05506, saving model to california_house2.h5
#
# Epoch 00015: val_loss did not improve from 1.05506
#
# Epoch 00016: val_loss did not improve from 1.05506
#
# Epoch 00017: val_loss did not improve from 1.05506
#
# Epoch 00018: val_loss improved from 1.05506 to 0.92159, saving model to california_house2.h5
#
# Epoch 00019: val_loss did not improve from 0.92159
#
# Epoch 00020: val_loss improved from 0.92159 to 0.83138, saving model to california_house2.h5
#
# Epoch 00021: val_loss improved from 0.83138 to 0.79716, saving model to california_house2.h5
#
# Epoch 00022: val_loss did not improve from 0.79716
#
# Epoch 00023: val_loss did not improve from 0.79716
#
# Epoch 00024: val_loss did not improve from 0.79716
#
# Epoch 00025: val_loss improved from 0.79716 to 0.74920, saving model to california_house2.h5
#
# Epoch 00026: val_loss improved from 0.74920 to 0.72213, saving model to california_house2.h5
#
# Epoch 00027: val_loss did not improve from 0.72213
#
# Epoch 00028: val_loss did not improve from 0.72213
#
# Epoch 00029: val_loss did not improve from 0.72213
#
# Epoch 00030: val_loss improved from 0.72213 to 0.66738, saving model to california_house2.h5
#
# Epoch 00031: val_loss did not improve from 0.66738
#
# Epoch 00032: val_loss did not improve from 0.66738
#
# Epoch 00033: val_loss did not improve from 0.66738
#
# Epoch 00034: val_loss did not improve from 0.66738
#
# Epoch 00035: val_loss did not improve from 0.66738
#
# Epoch 00036: val_loss did not improve from 0.66738
#
# Epoch 00037: val_loss did not improve from 0.66738
#
# Epoch 00038: val_loss did not improve from 0.66738
#
# Epoch 00039: val_loss did not improve from 0.66738
#
# Epoch 00040: val_loss did not improve from 0.66738
#
# Epoch 00041: val_loss improved from 0.66738 to 0.62987, saving model to california_house2.h5
#
# Epoch 00042: val_loss did not improve from 0.62987
#
# Epoch 00043: val_loss did not improve from 0.62987
#
# Epoch 00044: val_loss did not improve from 0.62987
#
# Epoch 00045: val_loss did not improve from 0.62987
#
# Epoch 00046: val_loss did not improve from 0.62987
#
# Epoch 00047: val_loss improved from 0.62987 to 0.61296, saving model to california_house2.h5
#
# Epoch 00048: val_loss did not improve from 0.61296
#
# Epoch 00049: val_loss did not improve from 0.61296
#
# Epoch 00050: val_loss improved from 0.61296 to 0.60726, saving model to california_house2.h5
#
# Epoch 00051: val_loss improved from 0.60726 to 0.59947, saving model to california_house2.h5
#
# Epoch 00052: val_loss did not improve from 0.59947
#
# Epoch 00053: val_loss did not improve from 0.59947
#
# Epoch 00054: val_loss did not improve from 0.59947
#
# Epoch 00055: val_loss did not improve from 0.59947
#
# Epoch 00056: val_loss did not improve from 0.59947
#
# Epoch 00057: val_loss did not improve from 0.59947
#
# Epoch 00058: val_loss did not improve from 0.59947
#
# Epoch 00059: val_loss improved from 0.59947 to 0.59083, saving model to california_house2.h5
#
# Epoch 00060: val_loss improved from 0.59083 to 0.58330, saving model to california_house2.h5
#
# Epoch 00061: val_loss did not improve from 0.58330
#
# Epoch 00062: val_loss did not improve from 0.58330
#
# Epoch 00063: val_loss did not improve from 0.58330
#
# Epoch 00064: val_loss did not improve from 0.58330
#
# Epoch 00065: val_loss did not improve from 0.58330
#
# Epoch 00066: val_loss improved from 0.58330 to 0.57470, saving model to california_house2.h5
#
# Epoch 00067: val_loss did not improve from 0.57470
#
# Epoch 00068: val_loss did not improve from 0.57470
#
# Epoch 00069: val_loss did not improve from 0.57470
#
# Epoch 00070: val_loss did not improve from 0.57470
#
# Epoch 00071: val_loss did not improve from 0.57470
#
# Epoch 00072: val_loss improved from 0.57470 to 0.55884, saving model to california_house2.h5
#
# Epoch 00073: val_loss improved from 0.55884 to 0.55548, saving model to california_house2.h5
#
# Epoch 00074: val_loss did not improve from 0.55548
#
# Epoch 00075: val_loss did not improve from 0.55548
#
# Epoch 00076: val_loss did not improve from 0.55548
#
# Epoch 00077: val_loss did not improve from 0.55548
#
# Epoch 00078: val_loss did not improve from 0.55548
#
# Epoch 00079: val_loss did not improve from 0.55548
#
# Epoch 00080: val_loss did not improve from 0.55548
#
# Epoch 00081: val_loss did not improve from 0.55548
#
# Epoch 00082: val_loss did not improve from 0.55548
#
# Epoch 00083: val_loss did not improve from 0.55548
#
# Epoch 00084: val_loss did not improve from 0.55548
#
# Epoch 00085: val_loss improved from 0.55548 to 0.55251, saving model to california_house2.h5
#
# Epoch 00086: val_loss did not improve from 0.55251
#
# Epoch 00087: val_loss did not improve from 0.55251
#
# Epoch 00088: val_loss did not improve from 0.55251
#
# Epoch 00089: val_loss did not improve from 0.55251
#
# Epoch 00090: val_loss did not improve from 0.55251
#
# Epoch 00091: val_loss did not improve from 0.55251
#
# Epoch 00092: val_loss improved from 0.55251 to 0.54033, saving model to california_house2.h5
#
# Epoch 00093: val_loss did not improve from 0.54033
#
# Epoch 00094: val_loss did not improve from 0.54033
#
# Epoch 00095: val_loss did not improve from 0.54033
#
# Epoch 00096: val_loss did not improve from 0.54033
#
# Epoch 00097: val_loss did not improve from 0.54033
#
# Epoch 00098: val_loss did not improve from 0.54033
#
# Epoch 00099: val_loss did not improve from 0.54033
#
# Epoch 00100: val_loss did not improve from 0.54033
#
# Epoch 00101: val_loss did not improve from 0.54033
#
# Epoch 00102: val_loss did not improve from 0.54033
#
# Epoch 00103: val_loss did not improve from 0.54033
#
# Epoch 00104: val_loss did not improve from 0.54033
#
# Epoch 00105: val_loss improved from 0.54033 to 0.53607, saving model to california_house2.h5
#
# Epoch 00106: val_loss improved from 0.53607 to 0.52761, saving model to california_house2.h5
#
# Epoch 00107: val_loss did not improve from 0.52761
#
# Epoch 00108: val_loss did not improve from 0.52761
#
# Epoch 00109: val_loss did not improve from 0.52761
#
# Epoch 00110: val_loss did not improve from 0.52761
#
# Epoch 00111: val_loss did not improve from 0.52761
#
# Epoch 00112: val_loss did not improve from 0.52761
#
# Epoch 00113: val_loss did not improve from 0.52761
#
# Epoch 00114: val_loss did not improve from 0.52761
#
# Epoch 00115: val_loss improved from 0.52761 to 0.52731, saving model to california_house2.h5
#
# Epoch 00116: val_loss did not improve from 0.52731
#
# Epoch 00117: val_loss did not improve from 0.52731
#
# Epoch 00118: val_loss did not improve from 0.52731
#
# Epoch 00119: val_loss did not improve from 0.52731
#
# Epoch 00120: val_loss did not improve from 0.52731
#
# Epoch 00121: val_loss did not improve from 0.52731
#
# Epoch 00122: val_loss did not improve from 0.52731
#
# Epoch 00123: val_loss did not improve from 0.52731
#
# Epoch 00124: val_loss did not improve from 0.52731
#
# Epoch 00125: val_loss did not improve from 0.52731
#
# Epoch 00126: val_loss did not improve from 0.52731
#
# Epoch 00127: val_loss did not improve from 0.52731
#
# Epoch 00128: val_loss did not improve from 0.52731
#
# Epoch 00129: val_loss did not improve from 0.52731
#
# Epoch 00130: val_loss did not improve from 0.52731
#
# Epoch 00131: val_loss improved from 0.52731 to 0.52655, saving model to california_house2.h5
#
# Epoch 00132: val_loss did not improve from 0.52655
#
# Epoch 00133: val_loss did not improve from 0.52655
#
# Epoch 00134: val_loss did not improve from 0.52655
#
# Epoch 00135: val_loss did not improve from 0.52655
#
# Epoch 00136: val_loss did not improve from 0.52655
#
# Epoch 00137: val_loss did not improve from 0.52655
#
# Epoch 00138: val_loss did not improve from 0.52655
#
# Epoch 00139: val_loss did not improve from 0.52655
#
# Epoch 00140: val_loss did not improve from 0.52655
#
# Epoch 00141: val_loss did not improve from 0.52655
#
# Epoch 00142: val_loss did not improve from 0.52655
#
# Epoch 00143: val_loss did not improve from 0.52655
#
# Epoch 00144: val_loss did not improve from 0.52655
#
# Epoch 00145: val_loss did not improve from 0.52655
#
# Epoch 00146: val_loss did not improve from 0.52655
#
# Epoch 00147: val_loss did not improve from 0.52655
#
# Epoch 00148: val_loss did not improve from 0.52655
#
# Epoch 00149: val_loss improved from 0.52655 to 0.51093, saving model to california_house2.h5
#
# Epoch 00150: val_loss did not improve from 0.51093
#
# Epoch 00151: val_loss did not improve from 0.51093
#
# Epoch 00152: val_loss did not improve from 0.51093
#
# Epoch 00153: val_loss did not improve from 0.51093
#
# Epoch 00154: val_loss did not improve from 0.51093
#
# Epoch 00155: val_loss did not improve from 0.51093
#
# Epoch 00156: val_loss did not improve from 0.51093
#
# Epoch 00157: val_loss did not improve from 0.51093
#
# Epoch 00158: val_loss did not improve from 0.51093
#
# Epoch 00159: val_loss did not improve from 0.51093
#
# Epoch 00160: val_loss did not improve from 0.51093
#
# Epoch 00161: val_loss did not improve from 0.51093
#
# Epoch 00162: val_loss did not improve from 0.51093
#
# Epoch 00163: val_loss did not improve from 0.51093
#
# Epoch 00164: val_loss did not improve from 0.51093
#
# Epoch 00165: val_loss did not improve from 0.51093
#
# Epoch 00166: val_loss did not improve from 0.51093
#
# Epoch 00167: val_loss did not improve from 0.51093
#
# Epoch 00168: val_loss improved from 0.51093 to 0.50663, saving model to california_house2.h5
#
# Epoch 00169: val_loss did not improve from 0.50663
#
# Epoch 00170: val_loss did not improve from 0.50663
#
# Epoch 00171: val_loss did not improve from 0.50663
#
# Epoch 00172: val_loss did not improve from 0.50663
#
# Epoch 00173: val_loss did not improve from 0.50663
#
# Epoch 00174: val_loss did not improve from 0.50663
#
# Epoch 00175: val_loss did not improve from 0.50663
#
# Epoch 00176: val_loss did not improve from 0.50663
#
# Epoch 00177: val_loss did not improve from 0.50663
#
# Epoch 00178: val_loss improved from 0.50663 to 0.50484, saving model to california_house2.h5
#
# Epoch 00179: val_loss did not improve from 0.50484
#
# Epoch 00180: val_loss did not improve from 0.50484
#
# Epoch 00181: val_loss did not improve from 0.50484
#
# Epoch 00182: val_loss did not improve from 0.50484
#
# Epoch 00183: val_loss did not improve from 0.50484
#
# Epoch 00184: val_loss did not improve from 0.50484
#
# Epoch 00185: val_loss did not improve from 0.50484
#
# Epoch 00186: val_loss improved from 0.50484 to 0.49412, saving model to california_house2.h5
#
# Epoch 00187: val_loss did not improve from 0.49412
#
# Epoch 00188: val_loss did not improve from 0.49412
#
# Epoch 00189: val_loss did not improve from 0.49412
#
# Epoch 00190: val_loss did not improve from 0.49412
#
# Epoch 00191: val_loss did not improve from 0.49412
#
# Epoch 00192: val_loss did not improve from 0.49412
#
# Epoch 00193: val_loss did not improve from 0.49412
#
# Epoch 00194: val_loss did not improve from 0.49412
#
# Epoch 00195: val_loss did not improve from 0.49412
#
# Epoch 00196: val_loss did not improve from 0.49412
#
# Epoch 00197: val_loss did not improve from 0.49412
#
# Epoch 00198: val_loss did not improve from 0.49412
#
# Epoch 00199: val_loss did not improve from 0.49412
#
# Epoch 00200: val_loss did not improve from 0.49412
#
# Epoch 00201: val_loss did not improve from 0.49412
#
# Epoch 00202: val_loss did not improve from 0.49412
#
# Epoch 00203: val_loss improved from 0.49412 to 0.48830, saving model to california_house2.h5
#
# Epoch 00204: val_loss did not improve from 0.48830
#
# Epoch 00205: val_loss improved from 0.48830 to 0.48552, saving model to california_house2.h5
#
# Epoch 00206: val_loss did not improve from 0.48552
#
# Epoch 00207: val_loss did not improve from 0.48552
#
# Epoch 00208: val_loss did not improve from 0.48552
#
# Epoch 00209: val_loss did not improve from 0.48552
#
# Epoch 00210: val_loss did not improve from 0.48552
#
# Epoch 00211: val_loss did not improve from 0.48552
#
# Epoch 00212: val_loss did not improve from 0.48552
#
# Epoch 00213: val_loss did not improve from 0.48552
#
# Epoch 00214: val_loss did not improve from 0.48552
#
# Epoch 00215: val_loss did not improve from 0.48552
#
# Epoch 00216: val_loss did not improve from 0.48552
#
# Epoch 00217: val_loss did not improve from 0.48552
#
# Epoch 00218: val_loss did not improve from 0.48552
#
# Epoch 00219: val_loss improved from 0.48552 to 0.48537, saving model to california_house2.h5
#
# Epoch 00220: val_loss did not improve from 0.48537
#
# Epoch 00221: val_loss did not improve from 0.48537
#
# Epoch 00222: val_loss did not improve from 0.48537
#
# Epoch 00223: val_loss did not improve from 0.48537
#
# Epoch 00224: val_loss did not improve from 0.48537
#
# Epoch 00225: val_loss did not improve from 0.48537
#
# Epoch 00226: val_loss did not improve from 0.48537
#
# Epoch 00227: val_loss did not improve from 0.48537
#
# Epoch 00228: val_loss did not improve from 0.48537
#
# Epoch 00229: val_loss did not improve from 0.48537
#
# Epoch 00230: val_loss did not improve from 0.48537
#
# Epoch 00231: val_loss did not improve from 0.48537
#
# Epoch 00232: val_loss did not improve from 0.48537
#
# Epoch 00233: val_loss did not improve from 0.48537
#
# Epoch 00234: val_loss did not improve from 0.48537
#
# Epoch 00235: val_loss did not improve from 0.48537
#
# Epoch 00236: val_loss did not improve from 0.48537
#
# Epoch 00237: val_loss did not improve from 0.48537
#
# Epoch 00238: val_loss did not improve from 0.48537
#
# Epoch 00239: val_loss did not improve from 0.48537
#
# Epoch 00240: val_loss did not improve from 0.48537
#
# Epoch 00241: val_loss did not improve from 0.48537
#
# Epoch 00242: val_loss did not improve from 0.48537
#
# Epoch 00243: val_loss did not improve from 0.48537
#
# Epoch 00244: val_loss did not improve from 0.48537
#
# Epoch 00245: val_loss did not improve from 0.48537
#
# Epoch 00246: val_loss did not improve from 0.48537
#
# Epoch 00247: val_loss did not improve from 0.48537
#
# Epoch 00248: val_loss did not improve from 0.48537
#
# Epoch 00249: val_loss did not improve from 0.48537

# %%
y_loss = hist2.history['loss']
y_vloss = hist2.history['val_loss']
xs = np.arange(1, len(y_loss)+1)

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(12,8))
plt.plot(xs, y_loss, label='train loss')
plt.plot(xs, y_vloss, label='validation loss')
plt.legend()
plt.grid()
plt.xlabel('Epoch')
plt.show()

# %% [markdown]
# - 평가

# %%
pred = model.predict(X_test)
pred2 = model2.predict(X_test)

# %%
from sklearn.metrics import mean_squared_error, r2_score

mean_squared_error(y_test, pred), r2_score(y_test, pred)
# Out:
# (0.6342579010419714, 0.5058067014515283)

# %%
mean_squared_error(y_test, pred2), r2_score(y_test, pred2)
# Out:
# (0.5505643103683617, 0.5710180477735977)

# %% [markdown]
# - 예측치 비교

# %%
df = pd.DataFrame({
    'y_test':y_test, 'pred':pred.flatten(), 'pred2':pred2.flatten()
})
df.head(10)
# Out:
#    y_test      pred     pred2
# 0   4.771  4.560508  3.557485
# 1   1.371  1.668998  1.115738
# 2   1.233  2.010825  1.115738
# 3   0.938  1.756583  1.115738
# 4   3.260  3.173606  3.159605
# 5   1.516  1.897010  1.409592
# 6   2.738  2.476142  2.324835
# 7   1.368  2.034904  1.695600
# 8   1.175  1.158225  1.115738
# 9   2.966  2.886039  2.697942

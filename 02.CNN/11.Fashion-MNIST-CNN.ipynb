# %% [markdown]
# # Fashion MNIST - CNN
# - 32 Conv2D layer
# - 64 Conv2D layer
# - MaxPooling2D layer
# - Dropout(0.25)
# - Flatten
# - Fully Connected Network(512)layer
# - Dropout(0.5)
# - Output(10)

# %%
import numpy as np
import tensorflow as tf
seed = 2022
np.random.seed(seed)
tf.random.set_seed(seed)

# %% [markdown]
# - 데이터 전처리

# %%
from tensorflow.keras.datasets import fashion_mnist
(X_train, y_train), (X_test, y_test) = fashion_mnist.load_data()

# %%
import matplotlib.pyplot as plt

plt.imshow(X_train[0], cmap='Greys');

# %%
class_names = ['T-shirt/top', 'Trouser', 'Pullover', 'Dress', 'Coat',
               'Sandal', 'Shirt', 'Sneaker', 'Bag', 'Ankle boot']
class_names[y_train[0]]
# Out:
# 'Ankle boot'

# %%
plt.figure(figsize=(14, 5))
for i in range(10):
    plt.subplot(2, 5, i+1)
    plt.imshow(X_train[i], cmap='Greys')
    plt.title(class_names[y_train[i]])
    plt.xticks([]); plt.yticks([])
plt.show()

# %%
X_train.shape, X_test.shape
# Out:
# ((60000, 28, 28), (10000, 28, 28))

# %%
# X data 정규화 및 차원 변경
X_train = X_train.reshape(-1, 28, 28, 1) / 255.
X_test = X_test.reshape(-1, 28, 28, 1) / 255.

# %%
# y data : one-hot encoing
from tensorflow.keras.utils import to_categorical
Y_train = to_categorical(y_train)
Y_test = to_categorical(y_test)

# %% [markdown]
# - 모델 정의, 설정, 학습, 평가

# %%
from tensorflow.keras.models import Sequential, load_model
from tensorflow.keras.layers import Dense, Conv2D, MaxPooling2D, Flatten, Dropout
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping

# %%
model = Sequential([
    Conv2D(32, (3,3), input_shape=(28,28,1), activation='relu'),
    Conv2D(64, (3,3), activation='relu'),
    MaxPooling2D(),
    Dropout(0.25),
    Flatten(),
    Dense(512, activation='relu'),
    Dropout(0.5),
    Dense(10, activation='softmax')
])
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 26, 26, 32)        320
#
#  conv2d_1 (Conv2D)           (None, 24, 24, 64)        18496
#
#  max_pooling2d (MaxPooling2D  (None, 12, 12, 64)       0
#  )
#
#  dropout (Dropout)           (None, 12, 12, 64)        0
#
#  flatten (Flatten)           (None, 9216)              0
#
#  dense (Dense)               (None, 512)               4719104
#
#  dropout_1 (Dropout)         (None, 512)               0
#
#  dense_1 (Dense)             (None, 10)                5130
#
# =================================================================
# Total params: 4,743,050
# Trainable params: 4,743,050
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# %%
model_path = 'best-fashion-mnist-cnn.h5'
checkpoint = ModelCheckpoint(model_path, save_best_only=True, verbose=1)
early_stop = EarlyStopping(patience=10)

# %%
hist = model.fit(
    X_train, Y_train, validation_split=0.2, batch_size=200, epochs=100,
    callbacks=[checkpoint, early_stop], verbose=0
)
# Out:
# Epoch 00001: val_loss improved from inf to 0.32902, saving model to best-fashion-mnist-cnn.h5
#
# Epoch 00002: val_loss improved from 0.32902 to 0.27628, saving model to best-fashion-mnist-cnn.h5
#
# Epoch 00003: val_loss improved from 0.27628 to 0.23936, saving model to best-fashion-mnist-cnn.h5
#
# Epoch 00004: val_loss improved from 0.23936 to 0.22944, saving model to best-fashion-mnist-cnn.h5
#
# Epoch 00005: val_loss did not improve from 0.22944
#
# Epoch 00006: val_loss improved from 0.22944 to 0.20969, saving model to best-fashion-mnist-cnn.h5
#
# Epoch 00007: val_loss improved from 0.20969 to 0.20091, saving model to best-fashion-mnist-cnn.h5
#
# Epoch 00008: val_loss did not improve from 0.20091
#
# Epoch 00009: val_loss improved from 0.20091 to 0.19898, saving model to best-fashion-mnist-cnn.h5
#
# Epoch 00010: val_loss did not improve from 0.19898
#
# Epoch 00011: val_loss did not improve from 0.19898
#
# Epoch 00012: val_loss did not improve from 0.19898
#
# Epoch 00013: val_loss did not improve from 0.19898
#
# Epoch 00014: val_loss did not improve from 0.19898
#
# Epoch 00015: val_loss did not improve from 0.19898
#
# Epoch 00016: val_loss did not improve from 0.19898
#
# Epoch 00017: val_loss did not improve from 0.19898
#
# Epoch 00018: val_loss did not improve from 0.19898
#
# Epoch 00019: val_loss did not improve from 0.19898

# %%
best_model = load_model(model_path)
best_model.evaluate(X_test, Y_test)
# Out:
# 313/313 [==============================] - 2s 5ms/step - loss: 0.2108 - accuracy: 0.9261
# [0.2108129858970642, 0.9261000156402588]

# %% [markdown]
# - 학습과정 시각화

# %%
y_acc = hist.history['accuracy']
y_vloss = hist.history['val_loss']
xs = np.arange(1, len(y_acc)+1)

# %%
plt.figure(figsize=(12,8))
plt.plot(xs, y_acc, 'o-', ms=3, label='train accuracy')
plt.plot(xs, y_vloss, 'o-', ms=3, label='validation loss')
plt.legend(), plt.grid(), plt.xlabel('Epoch')
plt.show()
